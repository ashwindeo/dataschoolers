# %% [markdown]
# ## Clean Up : School Demographic Info (schools.csv)

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %%
# Load schools.csv (raw data)
sdf_v0  = pd.read_csv("tempdata/schools.csv")
sdf_v0.shape

# %%
sc_drdf = pd.read_csv("tempdata/schools_rc.csv") # schools.csv column [d]rop [r]ename
sdf_v1  = sdf_v0.copy(deep=True)

# %%
for index, row in sc_drdf.iterrows():
    current_colname = str(row['Raw Column Name'])
    new_colname     = str(row['New Column Name'])
    if new_colname == "drop":
        #print "Dropping : ", current_colname
        sdf_v1.drop(current_colname, axis=1, inplace=True)
    else :
        #print "Renaming : ", current_colname, " --> ", new_colname
        sdf_v1.rename(columns={current_colname : new_colname    }, inplace=True)

sdf_v1.shape
# Out:
# (99074, 333)

# %% [markdown]
# ##### School Demographics : Column Notations
#
# | Notation       | Description                              |
# | :------------- | ---------------------------------------- |
# | pk             | School Year : Prekindergarten            |
# | k              | School Year : Kindergarten               |
# | g (g1,g2… g12) | School Year : Grade (Grade1, Grade2… Grade12) |
# | ug             | School Year : Ungraded                   |
# | an             | Race : American Indian/Asian Native      |
# | a              | Race : Asian/Pacific Islander            |
# | h              | Race : Hispanic                          |
# | b              | Race : Black                             |
# | w              | Race : White                             |
# | hp             | Race : Hawaiian Native/Pacific Islander  |
# | mr             | Race : Two or more races                 |
# | m              | Sex : Male                               |
# | f              | Sex : Female                             |

# %%
#sdf_v1.to_csv("tempdata/schools_v1.csv")
#sdf_v1 = pd.read_csv("tempdata/schools_v1.csv")

# %%
# Trimming cells that contain :
# ="abc" to abc
#  "abc" to abc
for i, col in enumerate(sdf_v1.columns):
    if sdf_v1[col].dtype == object:
        sdf_v1[col] = sdf_v1[col].str.replace('="', '')
        sdf_v1[col] = sdf_v1[col].str.replace('"', '')

# %%
# Replacing Missing Data / NA / Bad Quality data with NaN
# Ref : http://pandas.pydata.org/pandas-docs/version/0.15.2/missing_data.html

sdf_v1 = sdf_v1.replace('\xe2\x80\x93', np.nan) # Replace "-" (Missing Data) with NaN
sdf_v1 = sdf_v1.replace('\xe2\x80\xa0', np.nan) # Replace "†" (Not Applicable) with NaN
sdf_v1 = sdf_v1.replace('\xe2\x80\xa1', np.nan) # Replace "‡" (Bad Quality) with NaN

# %%
# Converting some columns to boolean data types by replacing "1-Yes", "2-No" to True & False resp.
tfmap =  {'1-Yes': True, '2-No': False}
vtfmap = {'A virtual school': True, 'Not a virtual school': False} # virtual_school
ltfmap = {'Yes under Community Eligibility Option (CEO)': True,
          'Yes participating without using any Provision or the CEO': True, 
          'Yes under Provision 3': True,
          'Yes under Provision 2': True,
          'Yes under Provision 1': True,
          'No': False }

sdf_v1 = sdf_v1.replace(tfmap)
sdf_v1 = sdf_v1.replace(vtfmap)
sdf_v1 = sdf_v1.replace(ltfmap)

# %%
sdf_v1.to_csv("tempdata/schools_v2.csv")
sdf_v2 = pd.read_csv("tempdata/schools_v2.csv")

# %%
for i, col in enumerate(sdf_v2.columns):
    print i," : ", col, " : ", sdf_v2[col].dtype
# Out:
# 0  :  Unnamed: 0  :  int64
# 1  :  ﻿School Name  :  object
# 2  :  state  :  object
# 3  :  state_abbr  :  object
# 4  :  school_id_nces  :  int64
# 5  :  agency_name  :  object
# 6  :  agency_id_nces  :  int64
# 7  :  county  :  object
# 8  :  data_available  :  object
# 9  :  data_na  :  object
# 10  :  city  :  object
# 11  :  zipcode  :  int64
# 12  :  school_type  :  object
# 13  :  agency_type  :  object
# 14  :  operational  :  object
# 15  :  charter_school  :  object
# 16  :  magnet_school  :  object
# 17  :  shared_time_school  :  object
# 18  :  location_type  :  object
# 19  :  title1_school_wide  :  object
# 20  :  title1_eligible  :  object
# 21  :  title1_status  :  object
# 22  :  latitude  :  float64
# 23  :  longitude  :  float64
# 24  :  school_id_state  :  object
# 25  :  agency_id_state  :  object
# 26  :  congressional_code  :  float64
# 27  :  virtual_school  :  object
# 28  :  lunch_program  :  object
# 29  :  offered_g_lowest  :  object
# 30  :  offered_g_highest  :  object
# 31  :  offered_pk  :  bool
# 32  :  offered_k  :  bool
# 33  :  offered_g1  :  bool
# 34  :  offered_g2  :  bool
# 35  :  offered_g3  :  bool
# 36  :  offered_g4  :  bool
# 37  :  offered_g5  :  bool
# 38  :  offered_g6  :  bool
# 39  :  offered_g7  :  bool
# 40  :  offered_g8  :  bool
# 41  :  offered_g9  :  bool
# 42  :  offered_g10  :  bool
# 43  :  offered_g11  :  bool
# 44  :  offered_g12  :  bool
# 45  :  offered_ug  :  bool
# 46  :  total_students  :  float64
# 47  :  lunch_free_eligible  :  float64
# 48  :  lunch_reduced_eligible  :  float64
# 49  :  lunch_total_free_and_reduced  :  float64
# 50  :  students_pk_k  :  float64
# 51  :  students_g1_g8  :  float64
# 52  :  students_g9_g12  :  float64
# 53  :  students_pk  :  float64
# 54  :  students_k  :  float64
# 55  :  students_g1  :  float64
# 56  :  students_g2  :  float64
# 57  :  students_g3  :  float64
# 58  :  students_g4  :  float64
# 59  :  students_g5  :  float64
# 60  :  students_g6  :  float64
# 61  :  students_g7  :  float64
# 62  :  students_g8  :  float64
# 63  :  students_g9  :  float64
# 64  :  students_g10  :  float64
# 65  :  students_g11  :  float64
# 66  :  students_g12  :  float64
# 67  :  students_ug  :  float64
# 68  :  students_m  :  float64
# 69  :  students_f  :  float64
# 70  :  students_an  :  float64
# 71  :  students_a  :  float64
# 72  :  students_h  :  float64
# 73  :  students_b  :  float64
# 74  :  students_w  :  float64
# 75  :  students_hp  :  float64
# 76  :  students_mr  :  float64
# 77  :  total_race  :  float64
# 78  :  an_m  :  float64
# 79  :  an_f  :  float64
# 80  :  a_m  :  float64
# 81  :  a_f  :  float64
# 82  :  h_m  :  float64
# 83  :  h_f  :  float64
# 84  :  b_m  :  float64
# 85  :  b_f  :  float64
# 86  :  w_m  :  float64
# 87  :  w_f  :  float64
# 88  :  hp_m  :  float64
# 89  :  hp_f  :  float64
# 90  :  mr_m  :  float64
# 91  :  mr_f  :  float64
# 92  :  pk_m  :  float64
# 93  :  pk_f  :  float64
# 94  :  k_m  :  float64
# 95  :  k_f  :  float64
# 96  :  g1_m  :  float64
# 97  :  g1_f  :  float64
# 98  :  g2_m  :  float64
# 99  :  g2_f  :  float64
# 100  :  g3_m  :  float64
# 101  :  g3_f  :  float64
# 102  :  g4_m  :  float64
# 103  :  g4_f  :  float64
# 104  :  g5_m  :  float64
# 105  :  g5_f  :  float64
# 106  :  g6_m  :  float64
# 107  :  g6_f  :  float64
# 108  :  g7_m  :  float64
# 109  :  g7_f  :  float64
# 110  :  g8_m  :  float64
# 111  :  g8_f  :  float64
# 112  :  g9_m  :  float64
# 113  :  g9_f  :  float64
# 114  :  g10_m  :  float64
# 115  :  g10_f  :  float64
# 116  :  g11_m  :  float64
# 117  :  g11_f  :  float64
# 118  :  g12_m  :  float64
# 119  :  g12_f  :  float64
# 120  :  gug_m  :  float64
# 121  :  gug_f  :  float64
# 122  :  pk_an_m  :  float64
# 123  :  pk_an_f  :  float64
# 124  :  pk_a_m  :  float64
# 125  :  pk_a_f  :  float64
# 126  :  pk_h_m  :  float64
# 127  :  pk_h_f  :  float64
# 128  :  pk_b_m  :  float64
# 129  :  pk_b_f  :  float64
# 130  :  pk_w_m  :  float64
# 131  :  pk_w_f  :  float64
# 132  :  pk_hp_m  :  float64
# 133  :  pk_hp_f  :  float64
# 134  :  pk_mr_m  :  float64
# 135  :  pk_mr_f  :  float64
# 136  :  k_an_m  :  float64
# 137  :  k_an_f  :  float64
# 138  :  k_a_m  :  float64
# 139  :  k_a_f  :  float64
# 140  :  k_h_m  :  float64
# 141  :  k_h_f  :  float64
# 142  :  k_b_m  :  float64
# 143  :  k_b_f  :  float64
# 144  :  k_w_m  :  float64
# 145  :  k_w_f  :  float64
# 146  :  k_hp_m  :  float64
# 147  :  k_hp_f  :  float64
# 148  :  k_mr_m  :  float64
# 149  :  k_mr_f  :  float64
# 150  :  g1_an_m  :  float64
# 151  :  g1_an_f  :  float64
# 152  :  g1_a_m  :  float64
# 153  :  g1_a_f  :  float64
# 154  :  g1_h_m  :  float64
# 155  :  g1_h_f  :  float64
# 156  :  g1_b_m  :  float64
# 157  :  g1_b_f  :  float64
# 158  :  g1_w_m  :  float64
# 159  :  g1_w_f  :  float64
# 160  :  g1_hp_m  :  float64
# 161  :  g1_hp_f  :  float64
# 162  :  g1_mr_m  :  float64
# 163  :  g1_mr_f  :  float64
# 164  :  g2_an_m  :  float64
# 165  :  g2_an_f  :  float64
# 166  :  g2_a_m  :  float64
# 167  :  g2_a_f  :  float64
# 168  :  g2_h_m  :  float64
# 169  :  g2_h_f  :  float64
# 170  :  g2_b_m  :  float64
# 171  :  g2_b_f  :  float64
# 172  :  g2_w_m  :  float64
# 173  :  g2_w_f  :  float64
# 174  :  g2_hp_m  :  float64
# 175  :  g2_hp_f  :  float64
# 176  :  g2_mr_m  :  float64
# 177  :  g2_mr_f  :  float64
# 178  :  g3_an_m  :  float64
# 179  :  g3_an_f  :  float64
# 180  :  g3_a_m  :  float64
# 181  :  g3_a_f  :  float64
# 182  :  g3_h_m  :  float64
# 183  :  g3_h_f  :  float64
# 184  :  g3_b_m  :  float64
# 185  :  g3_b_f  :  float64
# 186  :  g3_w_m  :  float64
# 187  :  g3_w_f  :  float64
# 188  :  g3_hp_m  :  float64
# 189  :  g3_hp_f  :  float64
# 190  :  g3_mr_m  :  float64
# 191  :  g3_mr_f  :  float64
# 192  :  g4_an_m  :  float64
# 193  :  g4_an_f  :  float64
# 194  :  g4_a_m  :  float64
# 195  :  g4_a_f  :  float64
# 196  :  g4_h_m  :  float64
# 197  :  g4_h_f  :  float64
# 198  :  g4_b_m  :  float64
# 199  :  g4_b_f  :  float64
# 200  :  g4_w_m  :  float64
# 201  :  g4_w_f  :  float64
# 202  :  g4_hp_m  :  float64
# 203  :  g4_hp_f  :  float64
# 204  :  g4_mr_m  :  float64
# 205  :  g4_mr_f  :  float64
# 206  :  g5_an_m  :  float64
# 207  :  g5_an_f  :  float64
# 208  :  g5_a_m  :  float64
# 209  :  g5_a_f  :  float64
# 210  :  g5_h_m  :  float64
# 211  :  g5_h_f  :  float64
# 212  :  g5_b_m  :  float64
# 213  :  g5_b_f  :  float64
# 214  :  g5_w_m  :  float64
# 215  :  g5_w_f  :  float64
# 216  :  g5_hp_m  :  float64
# 217  :  g5_hp_f  :  float64
# 218  :  g5_mr_m  :  float64
# 219  :  g5_mr_f  :  float64
# 220  :  g6_an_m  :  float64
# 221  :  g6_an_f  :  float64
# 222  :  g6_a_m  :  float64
# 223  :  g6_a_f  :  float64
# 224  :  g6_h_m  :  float64
# 225  :  g6_h_f  :  float64
# 226  :  g6_b_m  :  float64
# 227  :  g6_b_f  :  float64
# 228  :  g6_w_m  :  float64
# 229  :  g6_w_f  :  float64
# 230  :  g6_hp_m  :  float64
# 231  :  g6_hp_f  :  float64
# 232  :  g6_mr_m  :  float64
# 233  :  g6_mr_f  :  float64
# 234  :  g7_an_m  :  float64
# 235  :  g7_an_f  :  float64
# 236  :  g7_a_m  :  float64
# 237  :  g7_a_f  :  float64
# 238  :  g7_h_m  :  float64
# 239  :  g7_h_f  :  float64
# 240  :  g7_b_m  :  float64
# 241  :  g7_b_f  :  float64
# 242  :  g7_w_m  :  float64
# 243  :  g7_w_f  :  float64
# 244  :  g7_hp_m  :  float64
# 245  :  g7_hp_f  :  float64
# 246  :  g7_mr_m  :  float64
# 247  :  g7_mr_f  :  float64
# 248  :  g8_an_m  :  float64
# 249  :  g8_an_f  :  float64
# 250  :  g8_a_m  :  float64
# 251  :  g8_a_f  :  float64
# 252  :  g8_h_m  :  float64
# 253  :  g8_h_f  :  float64
# 254  :  g8_b_m  :  float64
# 255  :  g8_b_f  :  float64
# 256  :  g8_w_m  :  float64
# 257  :  g8_w_f  :  float64
# 258  :  g8_hp_m  :  float64
# 259  :  g8_hp_f  :  float64
# 260  :  g8_mr_m  :  float64
# 261  :  g8_mr_f  :  float64
# 262  :  g9_an_m  :  float64
# 263  :  g9_an_f  :  float64
# 264  :  g9_a_m  :  float64
# 265  :  g9_a_f  :  float64
# 266  :  g9_h_m  :  float64
# 267  :  g9_h_f  :  float64
# 268  :  g9_b_m  :  float64
# 269  :  g9_b_f  :  float64
# 270  :  g9_w_m  :  float64
# 271  :  g9_w_f  :  float64
# 272  :  g9_hp_m  :  float64
# 273  :  g9_hp_f  :  float64
# 274  :  g9_mr_m  :  float64
# 275  :  g9_mr_f  :  float64
# 276  :  g10_an_m  :  float64
# 277  :  g10_an_f  :  float64
# 278  :  g10_a_m  :  float64
# 279  :  g10_a_f  :  float64
# 280  :  g10_h_m  :  float64
# 281  :  g10_h_f  :  float64
# 282  :  g10_b_m  :  float64
# 283  :  g10_b_f  :  float64
# 284  :  g10_w_m  :  float64
# 285  :  g10_w_f  :  float64
# 286  :  g10_hp_m  :  float64
# 287  :  g10_hp_f  :  float64
# 288  :  g10_mr_m  :  float64
# 289  :  g10_mr_f  :  float64
# 290  :  g11_an_m  :  float64
# 291  :  g11_an_f  :  float64
# 292  :  g11_a_m  :  float64
# 293  :  g11_a_f  :  float64
# 294  :  g11_h_m  :  float64
# 295  :  g11_h_f  :  float64
# 296  :  g11_b_m  :  float64
# 297  :  g11_b_f  :  float64
# 298  :  g11_w_m  :  float64
# 299  :  g11_w_f  :  float64
# 300  :  g11_hp_m  :  float64
# 301  :  g11_hp_f  :  float64
# 302  :  g11_mr_m  :  float64
# 303  :  g11_mr_f  :  float64
# 304  :  g12_an_m  :  float64
# 305  :  g12_an_f  :  float64
# 306  :  g12_a_m  :  float64
# 307  :  g12_a_f  :  float64
# 308  :  g12_h_m  :  float64
# 309  :  g12_h_f  :  float64
# 310  :  g12_b_m  :  float64
# 311  :  g12_b_f  :  float64
# 312  :  g12_w_m  :  float64
# 313  :  g12_w_f  :  float64
# 314  :  g12_hp_m  :  float64
# 315  :  g12_hp_f  :  float64
# 316  :  g12_mr_m  :  float64
# 317  :  g12_mr_f  :  float64
# 318  :  gug_an_m  :  float64
# 319  :  gug_an_f  :  float64
# 320  :  gug_a_m  :  float64
# 321  :  gug_a_f  :  float64
# 322  :  gug_h_m  :  float64
# 323  :  gug_h_f  :  float64
# 324  :  gug_b_m  :  float64
# 325  :  gug_b_f  :  float64
# 326  :  gug_w_m  :  float64
# 327  :  gug_w_f  :  float64
# 328  :  gug_hp_m  :  float64
# 329  :  gug_hp_f  :  float64
# 330  :  gug_mr_m  :  float64
# 331  :  gug_mr_f  :  float64
# 332  :  teacher_fulltime  :  float64
# 333  :  pupil_teacher_ratio  :  float64
